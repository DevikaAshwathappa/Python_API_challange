# %% [markdown]
# # WeatherPy
# ----
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
import json
import scipy.stats as st
from scipy.stats import linregress

# Import API key
from api_keys import weather_api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 608

# %%
city_name_list = []
cloudiness_list = []
country_list = []
date_list = []
humidity_list = []
lat_list = []
lng_list = []
max_temp_list = []
wind_speed_list = []
index_counter = 0
set_counter = 1

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
print("Beginning Data Retrieval ")
print("-----------------------------")

base_url = "http://api.openweathermap.org/data/2.5/weather?"
units = "imperial"
query_url = f"{base_url}appid={weather_api_key}&units={units}&q="


# For each city name in cities list, do below things...
for index, city in enumerate(cities, start = 1):
    try:
        response = requests.get(query_url + city).json()
        city_name_list.append(response["name"])
        cloudiness_list.append(response["clouds"]["all"])
        country_list.append(response["sys"]["country"])
        date_list.append(response["dt"])
        humidity_list.append(response["main"]["humidity"])
        lat_list.append(response["coord"]["lat"])
        lng_list.append(response["coord"]["lon"])
        max_temp_list.append(response['main']['temp_max'])
        wind_speed_list.append(response["wind"]["speed"])
        if index_counter > 49:
            index_counter = 0
            set_counter = set_counter + 1
    
        else:
            index_counter = index_counter + 1
            
        print(f"Processing Record {index_counter} of Set {set_counter} : {city}") 
  
    except(KeyError, IndexError):
        print("City not found. Skipping...")
        
print("-----------------------------")
print("Data Retrieval Complete")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 : luderitz
# Processing Record 2 of Set 1 : sur
# Processing Record 3 of Set 1 : ahipara
# Processing Record 4 of Set 1 : pimenta bueno
# Processing Record 5 of Set 1 : nikolskoye
# Processing Record 6 of Set 1 : touros
# Processing Record 7 of Set 1 : catalina foothills
# Processing Record 8 of Set 1 : hermanus
# Processing Record 9 of Set 1 : lebu
# Processing Record 10 of Set 1 : manta
# Processing Record 11 of Set 1 : aras
# Processing Record 12 of Set 1 : rikitea
# City not found. Skipping...
# Processing Record 13 of Set 1 : coite do noia
# Processing Record 14 of Set 1 : ushuaia
# Processing Record 15 of Set 1 : hobart
# Processing Record 16 of Set 1 : vila franca do campo
# Processing Record 17 of Set 1 : general roca
# Processing Record 18 of Set 1 : hilo
# City not found. Skipping...
# Processing Record 19 of Set 1 : clyde river
# Processing Record 20 of Set 1 : cape town
# Processing Record 21 of Set 1 : avarua
# Processing Record 22 of Set 1 : puerto ayora
# Processing Record 23 of Set 1 : chokurdakh
# City not found. Skipping...
# Processing Record 24 of Set 1 : bilibino
# Processing Record 25 of Set 1 : butaritari
# Processing Record 26 of Set 1 : new norfolk
# Processing Record 27 of Set 1 : roma
# Processing Record 28 of Set 1 : arteaga
# Processing Record 29 of Set 1 : camacari
# Processing Record 30 of Set 1 : oranjemund
# Processing Record 31 of Set 1 : poum
# City not found. Skipping...
# Processing Record 32 of Set 1 : maneadero
# Processing Record 33 of Set 1 : atuona
# Processing Record 34 of Set 1 : henderson
# Processing Record 35 of Set 1 : qaanaaq
# Processing Record 36 of Set 1 : urumqi
# Processing Record 37 of Set 1 : khatanga
# Processing Record 38 of Set 1 : bluff
# Processing Record 39 of Set 1 : east london
# Processing Record 40 of Set 1 : vaini
# Processing Record 41 of Set 1 : babu
# Processing Record 42 of Set 1 : nanortalik
# Processing Record 43 of Set 1 : busselton
# Processing Record 44 of Set 1 : barrow
# Processing Record 45 of Set 1 : cayenne
# Processing Record 46 of Set 1 : hobyo
# Processing Record 47 of Set 1 : esperance
# Processing Record 48 of Set 1 : pareora
# Processing Record 49 of Set 1 : port elizabeth
# Processing Record 50 of Set 1 : port blair
# Processing Record 0 of Set 2 : kangundo
# Processing Record 1 of Set 2 : ponta do sol
# Processing Record 2 of Set 2 : saint george
# Processing Record 3 of Set 2 : punta arenas
# Processing Record 4 of Set 2 : kasongo
# Processing Record 5 of Set 2 : ovsyanka
# Processing Record 6 of Set 2 : tasiilaq
# Processing Record 7 of Set 2 : shubarshi
# City not found. Skipping...
# Processing Record 8 of Set 2 : yarkovo
# Processing Record 9 of Set 2 : ajdabiya
# Processing Record 10 of Set 2 : dibulla
# Processing Record 11 of Set 2 : santa flavia
# Processing Record 12 of Set 2 : hithadhoo
# Processing Record 13 of Set 2 : asau
# Processing Record 14 of Set 2 : dikson
# Processing Record 15 of Set 2 : mar del plata
# Processing Record 16 of Set 2 : laredo
# Processing Record 17 of Set 2 : san quintin
# Processing Record 18 of Set 2 : labuhan
# Processing Record 19 of Set 2 : owando
# Processing Record 20 of Set 2 : kodiak
# Processing Record 21 of Set 2 : puerto escondido
# Processing Record 22 of Set 2 : saquarema
# Processing Record 23 of Set 2 : penzance
# Processing Record 24 of Set 2 : naryan-mar
# Processing Record 25 of Set 2 : yellowknife
# Processing Record 26 of Set 2 : sambava
# Processing Record 27 of Set 2 : albany
# Processing Record 28 of Set 2 : tombouctou
# Processing Record 29 of Set 2 : neiafu
# Processing Record 30 of Set 2 : umm kaddadah
# Processing Record 31 of Set 2 : katangli
# Processing Record 32 of Set 2 : moba
# Processing Record 33 of Set 2 : jamestown
# Processing Record 34 of Set 2 : christiansburg
# Processing Record 35 of Set 2 : laguna
# Processing Record 36 of Set 2 : dwarka
# Processing Record 37 of Set 2 : hounde
# Processing Record 38 of Set 2 : samarai
# Processing Record 39 of Set 2 : mataura
# Processing Record 40 of Set 2 : carnarvon
# Processing Record 41 of Set 2 : roald
# Processing Record 42 of Set 2 : nuuk
# Processing Record 43 of Set 2 : chuy
# Processing Record 44 of Set 2 : rongcheng
# Processing Record 45 of Set 2 : tuktoyaktuk
# Processing Record 46 of Set 2 : hasaki
# Processing Record 47 of Set 2 : fort nelson
# Processing Record 48 of Set 2 : upernavik
# Processing Record 49 of Set 2 : nagato
# Processing Record 50 of Set 2 : alofi
# Processing Record 0 of Set 3 : kashi
# Processing Record 1 of Set 3 : geraldton
# Processing Record 2 of Set 3 : talnakh
# Processing Record 3 of Set 3 : chkalovsk
# City not found. Skipping...
# Processing Record 4 of Set 3 : launceston
# Processing Record 5 of Set 3 : cabo san lucas
# Processing Record 6 of Set 3 : arraial do cabo
# Processing Record 7 of Set 3 : puerto carreno
# Processing Record 8 of Set 3 : kapaa
# City not found. Skipping...
# Processing Record 9 of Set 3 : fare
# Processing Record 10 of Set 3 : port hawkesbury
# Processing Record 11 of Set 3 : longyearbyen
# Processing Record 12 of Set 3 : saskylakh
# Processing Record 13 of Set 3 : narsaq
# Processing Record 14 of Set 3 : aklavik
# Processing Record 15 of Set 3 : biloela
# Processing Record 16 of Set 3 : wojkowice
# Processing Record 17 of Set 3 : adrar
# Processing Record 18 of Set 3 : kruisfontein
# Processing Record 19 of Set 3 : kita
# Processing Record 20 of Set 3 : fairbanks
# Processing Record 21 of Set 3 : anicuns
# Processing Record 22 of Set 3 : cacu
# Processing Record 23 of Set 3 : turukhansk
# Processing Record 24 of Set 3 : barcelos
# Processing Record 25 of Set 3 : balabac
# Processing Record 26 of Set 3 : tabou
# Processing Record 27 of Set 3 : port alfred
# Processing Record 28 of Set 3 : baker city
# Processing Record 29 of Set 3 : salalah
# Processing Record 30 of Set 3 : qaqortoq
# Processing Record 31 of Set 3 : souillac
# Processing Record 32 of Set 3 : thompson
# Processing Record 33 of Set 3 : nago
# Processing Record 34 of Set 3 : namatanai
# Processing Record 35 of Set 3 : saint-philippe
# Processing Record 36 of Set 3 : navan
# Processing Record 37 of Set 3 : kavaratti
# Processing Record 38 of Set 3 : riyadh
# Processing Record 39 of Set 3 : kimbe
# Processing Record 40 of Set 3 : lavrentiya
# Processing Record 41 of Set 3 : bredasdorp
# Processing Record 42 of Set 3 : gwadar
# Processing Record 43 of Set 3 : reno
# Processing Record 44 of Set 3 : noumea
# Processing Record 45 of Set 3 : magadan
# Processing Record 46 of Set 3 : opuwo
# Processing Record 47 of Set 3 : cidreira
# Processing Record 48 of Set 3 : dingle
# Processing Record 49 of Set 3 : erzin
# City not found. Skipping...
# Processing Record 50 of Set 3 : prince rupert
# Processing Record 0 of Set 4 : katsuura
# Processing Record 1 of Set 4 : norman wells
# Processing Record 2 of Set 4 : perth
# Processing Record 3 of Set 4 : nador
# Processing Record 4 of Set 4 : orbetello
# Processing Record 5 of Set 4 : ostrovnoy
# City not found. Skipping...
# Processing Record 6 of Set 4 : tura
# Processing Record 7 of Set 4 : pendleton
# Processing Record 8 of Set 4 : mount gambier
# Processing Record 9 of Set 4 : nenjiang
# City not found. Skipping...
# Processing Record 10 of Set 4 : los llanos de aridane
# Processing Record 11 of Set 4 : romitan
# Processing Record 12 of Set 4 : torbay
# Processing Record 13 of Set 4 : karratha
# Processing Record 14 of Set 4 : vuktyl
# Processing Record 15 of Set 4 : elko
# Processing Record 16 of Set 4 : faanui
# Processing Record 17 of Set 4 : bethel
# Processing Record 18 of Set 4 : ribeira grande
# City not found. Skipping...
# Processing Record 19 of Set 4 : beringovskiy
# Processing Record 20 of Set 4 : lata
# Processing Record 21 of Set 4 : vila velha
# Processing Record 22 of Set 4 : sola
# Processing Record 23 of Set 4 : manaure
# Processing Record 24 of Set 4 : teya
# Processing Record 25 of Set 4 : padang
# Processing Record 26 of Set 4 : grindavik
# Processing Record 27 of Set 4 : burayevo
# Processing Record 28 of Set 4 : praia
# Processing Record 29 of Set 4 : usinsk
# Processing Record 30 of Set 4 : emborion
# Processing Record 31 of Set 4 : lampang
# Processing Record 32 of Set 4 : loreto
# Processing Record 33 of Set 4 : iqaluit
# Processing Record 34 of Set 4 : fortuna
# Processing Record 35 of Set 4 : caravelas
# Processing Record 36 of Set 4 : santa isabel
# Processing Record 37 of Set 4 : balkanabat
# Processing Record 38 of Set 4 : bengkulu
# Processing Record 39 of Set 4 : madimba
# Processing Record 40 of Set 4 : aksarka
# Processing Record 41 of Set 4 : juneau
# Processing Record 42 of Set 4 : faya
# Processing Record 43 of Set 4 : byron bay
# Processing Record 44 of Set 4 : srednekolymsk
# Processing Record 45 of Set 4 : muroto
# Processing Record 46 of Set 4 : leningradskiy
# Processing Record 47 of Set 4 : quatre cocos
# Processing Record 48 of Set 4 : kaohsiung
# Processing Record 49 of Set 4 : vaasa
# Processing Record 50 of Set 4 : nalut
# Processing Record 0 of Set 5 : talaya
# Processing Record 1 of Set 5 : nahariyya
# Processing Record 2 of Set 5 : hofn
# Processing Record 3 of Set 5 : solton
# Processing Record 4 of Set 5 : port hardy
# Processing Record 5 of Set 5 : zhigansk
# Processing Record 6 of Set 5 : davila
# Processing Record 7 of Set 5 : coihaique
# Processing Record 8 of Set 5 : lady frere
# Processing Record 9 of Set 5 : bichura
# Processing Record 10 of Set 5 : sisimiut
# Processing Record 11 of Set 5 : castro
# Processing Record 12 of Set 5 : aykhal
# Processing Record 13 of Set 5 : bambous virieux
# Processing Record 14 of Set 5 : sao gabriel da cachoeira
# Processing Record 15 of Set 5 : stromness
# Processing Record 16 of Set 5 : georgetown
# Processing Record 17 of Set 5 : constitucion
# Processing Record 18 of Set 5 : severo-kurilsk
# Processing Record 19 of Set 5 : san patricio
# Processing Record 20 of Set 5 : provideniya
# Processing Record 21 of Set 5 : ixtapa
# Processing Record 22 of Set 5 : malm
# Processing Record 23 of Set 5 : santiago del estero
# Processing Record 24 of Set 5 : lowestoft
# City not found. Skipping...
# Processing Record 25 of Set 5 : egvekinot
# Processing Record 26 of Set 5 : ust-kuyga
# Processing Record 27 of Set 5 : villa carlos paz
# Processing Record 28 of Set 5 : victoria
# Processing Record 29 of Set 5 : mahebourg
# Processing Record 30 of Set 5 : plettenberg bay
# Processing Record 31 of Set 5 : deputatskiy
# Processing Record 32 of Set 5 : nome
# Processing Record 33 of Set 5 : salumbar
# Processing Record 34 of Set 5 : santa maria
# Processing Record 35 of Set 5 : taree
# Processing Record 36 of Set 5 : itoman
# Processing Record 37 of Set 5 : kalinagar
# Processing Record 38 of Set 5 : kutum
# Processing Record 39 of Set 5 : tiksi
# Processing Record 40 of Set 5 : isangel
# Processing Record 41 of Set 5 : mangochi
# Processing Record 42 of Set 5 : hede
# City not found. Skipping...
# Processing Record 43 of Set 5 : walvis bay
# City not found. Skipping...
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 44 of Set 5 : chernyshevskiy
# Processing Record 45 of Set 5 : cacule
# Processing Record 46 of Set 5 : yar-sale
# Processing Record 47 of Set 5 : codrington
# Processing Record 48 of Set 5 : oktyabrskoye
# Processing Record 49 of Set 5 : quelimane
# Processing Record 50 of Set 5 : bakel
# Processing Record 0 of Set 6 : nanhai
# Processing Record 1 of Set 6 : morant bay
# Processing Record 2 of Set 6 : ambilobe
# Processing Record 3 of Set 6 : carambei
# Processing Record 4 of Set 6 : mehamn
# Processing Record 5 of Set 6 : rudnogorsk
# Processing Record 6 of Set 6 : airai
# Processing Record 7 of Set 6 : vista hermosa
# City not found. Skipping...
# Processing Record 8 of Set 6 : tigil
# Processing Record 9 of Set 6 : shahrud
# Processing Record 10 of Set 6 : waipawa
# Processing Record 11 of Set 6 : pochutla
# Processing Record 12 of Set 6 : aksay
# City not found. Skipping...
# Processing Record 13 of Set 6 : tambura
# Processing Record 14 of Set 6 : ancud
# Processing Record 15 of Set 6 : pisco
# Processing Record 16 of Set 6 : alekseyevsk
# Processing Record 17 of Set 6 : grande prairie
# Processing Record 18 of Set 6 : cherskiy
# Processing Record 19 of Set 6 : the valley
# Processing Record 20 of Set 6 : awbari
# Processing Record 21 of Set 6 : calama
# Processing Record 22 of Set 6 : mamlyutka
# Processing Record 23 of Set 6 : jaen
# Processing Record 24 of Set 6 : marzuq
# Processing Record 25 of Set 6 : san blas
# Processing Record 26 of Set 6 : anori
# Processing Record 27 of Set 6 : szabadbattyan
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 28 of Set 6 : almaznyy
# Processing Record 29 of Set 6 : nouakchott
# Processing Record 30 of Set 6 : vrede
# Processing Record 31 of Set 6 : mikhaylovsk
# Processing Record 32 of Set 6 : cururupu
# Processing Record 33 of Set 6 : slave lake
# Processing Record 34 of Set 6 : whitianga
# Processing Record 35 of Set 6 : mayo
# Processing Record 36 of Set 6 : itarema
# Processing Record 37 of Set 6 : rantepao
# Processing Record 38 of Set 6 : ariquemes
# Processing Record 39 of Set 6 : omboue
# Processing Record 40 of Set 6 : wasilla
# Processing Record 41 of Set 6 : esso
# Processing Record 42 of Set 6 : hamilton
# City not found. Skipping...
# Processing Record 43 of Set 6 : anloga
# Processing Record 44 of Set 6 : bud
# Processing Record 45 of Set 6 : peleduy
# Processing Record 46 of Set 6 : peterhead
# Processing Record 47 of Set 6 : sao joao da barra
# Processing Record 48 of Set 6 : katobu
# City not found. Skipping...
# Processing Record 49 of Set 6 : moose factory
# City not found. Skipping...
# Processing Record 50 of Set 6 : huittinen
# Processing Record 0 of Set 7 : kiruna
# Processing Record 1 of Set 7 : camacha
# Processing Record 2 of Set 7 : ilulissat
# Processing Record 3 of Set 7 : kaseda
# City not found. Skipping...
# Processing Record 4 of Set 7 : iralaya
# Processing Record 5 of Set 7 : roebourne
# Processing Record 6 of Set 7 : sitka
# Processing Record 7 of Set 7 : san policarpo
# Processing Record 8 of Set 7 : akyab
# City not found. Skipping...
# Processing Record 9 of Set 7 : kuytun
# Processing Record 10 of Set 7 : zaqatala
# Processing Record 11 of Set 7 : korla
# Processing Record 12 of Set 7 : borda da mata
# City not found. Skipping...
# Processing Record 13 of Set 7 : espinho
# Processing Record 14 of Set 7 : andros town
# Processing Record 15 of Set 7 : avera
# Processing Record 16 of Set 7 : araouane
# Processing Record 17 of Set 7 : sainte-suzanne
# Processing Record 18 of Set 7 : ramgarh
# Processing Record 19 of Set 7 : tongliao
# Processing Record 20 of Set 7 : timmins
# Processing Record 21 of Set 7 : kaitangata
# Processing Record 22 of Set 7 : tanout
# Processing Record 23 of Set 7 : kismayo
# Processing Record 24 of Set 7 : antalya
# Processing Record 25 of Set 7 : iberia
# Processing Record 26 of Set 7 : qafqafa
# Processing Record 27 of Set 7 : guangyuan
# City not found. Skipping...
# Processing Record 28 of Set 7 : severo-yeniseyskiy
# Processing Record 29 of Set 7 : goderich
# Processing Record 30 of Set 7 : brae
# Processing Record 31 of Set 7 : victoria point
# Processing Record 32 of Set 7 : belaya gora
# Processing Record 33 of Set 7 : jieshi
# Processing Record 34 of Set 7 : macon
# Processing Record 35 of Set 7 : mashhad
# Processing Record 36 of Set 7 : pangody
# Processing Record 37 of Set 7 : leo
# City not found. Skipping...
# Processing Record 38 of Set 7 : narok
# Processing Record 39 of Set 7 : port lincoln
# Processing Record 40 of Set 7 : adelaide
# Processing Record 41 of Set 7 : atherton
# Processing Record 42 of Set 7 : makakilo city
# Processing Record 43 of Set 7 : voghera
# Processing Record 44 of Set 7 : voh
# Processing Record 45 of Set 7 : chickasha
# Processing Record 46 of Set 7 : taltal
# Processing Record 47 of Set 7 : la ronge
# Processing Record 48 of Set 7 : maltahohe
# Processing Record 49 of Set 7 : chlorakas
# Processing Record 50 of Set 7 : kirakira
# Processing Record 0 of Set 8 : jutai
# Processing Record 1 of Set 8 : chegdomyn
# Processing Record 2 of Set 8 : dodge city
# Processing Record 3 of Set 8 : rincon
# Processing Record 4 of Set 8 : pacific grove
# Processing Record 5 of Set 8 : zhezkazgan
# Processing Record 6 of Set 8 : berlevag
# Processing Record 7 of Set 8 : ayan
# Processing Record 8 of Set 8 : severnyy
# Processing Record 9 of Set 8 : cortez
# Processing Record 10 of Set 8 : komsomolskiy
# Processing Record 11 of Set 8 : tucuman
# Processing Record 12 of Set 8 : verkhnyaya inta
# Processing Record 13 of Set 8 : toamasina
# City not found. Skipping...
# Processing Record 14 of Set 8 : iquique
# Processing Record 15 of Set 8 : minsk
# Processing Record 16 of Set 8 : muli
# Processing Record 17 of Set 8 : ormara
# Processing Record 18 of Set 8 : xichang
# Processing Record 19 of Set 8 : botucatu
# Processing Record 20 of Set 8 : honiara
# Processing Record 21 of Set 8 : santa catalina
# Processing Record 22 of Set 8 : lasa
# Processing Record 23 of Set 8 : buncrana
# Processing Record 24 of Set 8 : lac du bonnet
# City not found. Skipping...
# Processing Record 25 of Set 8 : marquette
# Processing Record 26 of Set 8 : seoul
# Processing Record 27 of Set 8 : telimele
# Processing Record 28 of Set 8 : tacoronte
# Processing Record 29 of Set 8 : shimoda
# Processing Record 30 of Set 8 : venice
# Processing Record 31 of Set 8 : rio gallegos
# Processing Record 32 of Set 8 : guerrero negro
# Processing Record 33 of Set 8 : nicoya
# Processing Record 34 of Set 8 : kenora
# Processing Record 35 of Set 8 : maraa
# Processing Record 36 of Set 8 : poso
# Processing Record 37 of Set 8 : brownsville
# Processing Record 38 of Set 8 : cam ranh
# Processing Record 39 of Set 8 : alyangula
# Processing Record 40 of Set 8 : la asuncion
# Processing Record 41 of Set 8 : lima
# Processing Record 42 of Set 8 : tsaritsani
# Processing Record 43 of Set 8 : dudinka
# Processing Record 44 of Set 8 : kasaragod
# City not found. Skipping...
# Processing Record 45 of Set 8 : san jeronimo
# Processing Record 46 of Set 8 : amga
# Processing Record 47 of Set 8 : vakhrushev
# Processing Record 48 of Set 8 : inta
# Processing Record 49 of Set 8 : kilifi
# Processing Record 50 of Set 8 : ouadda
# Processing Record 0 of Set 9 : baykit
# Processing Record 1 of Set 9 : hovd
# Processing Record 2 of Set 9 : hokitika
# Processing Record 3 of Set 9 : anadyr
# Processing Record 4 of Set 9 : richards bay
# Processing Record 5 of Set 9 : caconda
# Processing Record 6 of Set 9 : suleja
# Processing Record 7 of Set 9 : atambua
# City not found. Skipping...
# Processing Record 8 of Set 9 : kaduqli
# Processing Record 9 of Set 9 : magistralnyy
# Processing Record 10 of Set 9 : pucallpa
# Processing Record 11 of Set 9 : atar
# Processing Record 12 of Set 9 : maceio
# Processing Record 13 of Set 9 : pacifica
# City not found. Skipping...
# Processing Record 14 of Set 9 : saint-joseph
# Processing Record 15 of Set 9 : te anau
# Processing Record 16 of Set 9 : berdigestyakh
# Processing Record 17 of Set 9 : pangkalanbuun
# Processing Record 18 of Set 9 : merauke
# Processing Record 19 of Set 9 : kutno
# Processing Record 20 of Set 9 : inuvik
# Processing Record 21 of Set 9 : saldanha
# Processing Record 22 of Set 9 : ghansor
# Processing Record 23 of Set 9 : westport
# City not found. Skipping...
# Processing Record 24 of Set 9 : tel aviv-yafo
# Processing Record 25 of Set 9 : ardabil
# City not found. Skipping...
# Processing Record 26 of Set 9 : purna
# Processing Record 27 of Set 9 : mantua
# Processing Record 28 of Set 9 : jinchang
# City not found. Skipping...
# Processing Record 29 of Set 9 : iglesias
# Processing Record 30 of Set 9 : oussouye
# Processing Record 31 of Set 9 : manokwari
# Processing Record 32 of Set 9 : college
# Processing Record 33 of Set 9 : heihe
# Processing Record 34 of Set 9 : flin flon
# Processing Record 35 of Set 9 : san pedro de macoris
# Processing Record 36 of Set 9 : hwange
# Processing Record 37 of Set 9 : muyezerskiy
# Processing Record 38 of Set 9 : pangai
# Processing Record 39 of Set 9 : muriwai beach
# Processing Record 40 of Set 9 : athabasca
# City not found. Skipping...
# Processing Record 41 of Set 9 : abu dhabi
# Processing Record 42 of Set 9 : tatarsk
# Processing Record 43 of Set 9 : kahului
# Processing Record 44 of Set 9 : baie-comeau
# Processing Record 45 of Set 9 : nizhnevartovsk
# Processing Record 46 of Set 9 : portland
# City not found. Skipping...
# Processing Record 47 of Set 9 : warrenton
# Processing Record 48 of Set 9 : sungaipenuh
# Processing Record 49 of Set 9 : oum hadjer
# Processing Record 50 of Set 9 : lorengau
# Processing Record 0 of Set 10 : pingliang
# Processing Record 1 of Set 10 : miraflores
# Processing Record 2 of Set 10 : itupiranga
# Processing Record 3 of Set 10 : shelburne
# Processing Record 4 of Set 10 : morondava
# Processing Record 5 of Set 10 : anzhero-sudzhensk
# Processing Record 6 of Set 10 : blairmore
# Processing Record 7 of Set 10 : mokhsogollokh
# Processing Record 8 of Set 10 : lazaro cardenas
# Processing Record 9 of Set 10 : bardiyah
# Processing Record 10 of Set 10 : beyneu
# Processing Record 11 of Set 10 : steamboat springs
# Processing Record 12 of Set 10 : kavieng
# Processing Record 13 of Set 10 : nouadhibou
# Processing Record 14 of Set 10 : keti bandar
# City not found. Skipping...
# Processing Record 15 of Set 10 : axim
# Processing Record 16 of Set 10 : shimsk
# Processing Record 17 of Set 10 : lernakert
# Processing Record 18 of Set 10 : calvinia
# Processing Record 19 of Set 10 : atasu
# City not found. Skipping...
# Processing Record 20 of Set 10 : behshahr
# Processing Record 21 of Set 10 : sept-iles
# Processing Record 22 of Set 10 : kaeo
# Processing Record 23 of Set 10 : druzhba
# Processing Record 24 of Set 10 : matagami
# Processing Record 25 of Set 10 : chirilagua
# Processing Record 26 of Set 10 : batagay-alyta
# Processing Record 27 of Set 10 : ambanja
# Processing Record 28 of Set 10 : gat
# Processing Record 29 of Set 10 : lekoni
# Processing Record 30 of Set 10 : nichinan
# Processing Record 31 of Set 10 : lompoc
# Processing Record 32 of Set 10 : gillette
# Processing Record 33 of Set 10 : yanam
# Processing Record 34 of Set 10 : surgut
# Processing Record 35 of Set 10 : masuda
# City not found. Skipping...
# Processing Record 36 of Set 10 : newport
# Processing Record 37 of Set 10 : anchorage
# Processing Record 38 of Set 10 : balad
# Processing Record 39 of Set 10 : dongsheng
# Processing Record 40 of Set 10 : chastyye
# Processing Record 41 of Set 10 : north platte
# Processing Record 42 of Set 10 : tuatapere
# Processing Record 43 of Set 10 : buala
# Processing Record 44 of Set 10 : tahoua
# Processing Record 45 of Set 10 : vestmannaeyjar
# Processing Record 46 of Set 10 : vardo
# Processing Record 47 of Set 10 : tezu
# Processing Record 48 of Set 10 : dayong
# Processing Record 49 of Set 10 : alexander city
# Processing Record 50 of Set 10 : tela
# Processing Record 0 of Set 11 : yeppoon
# Processing Record 1 of Set 11 : belmonte
# Processing Record 2 of Set 11 : rameshki
# Processing Record 3 of Set 11 : pimentel
# Processing Record 4 of Set 11 : bogashevo
# Processing Record 5 of Set 11 : hibbing
# Processing Record 6 of Set 11 : klaksvik
# Processing Record 7 of Set 11 : damghan
# Processing Record 8 of Set 11 : port-gentil
# Processing Record 9 of Set 11 : yarada
# Processing Record 10 of Set 11 : burley
# Processing Record 11 of Set 11 : kununurra
# Processing Record 12 of Set 11 : chicama
# Processing Record 13 of Set 11 : golspie
# Processing Record 14 of Set 11 : chara
# Processing Record 15 of Set 11 : fukue
# Processing Record 16 of Set 11 : bathsheba
# Processing Record 17 of Set 11 : fonte boa
# Processing Record 18 of Set 11 : tautira
# Processing Record 19 of Set 11 : saint anthony
# City not found. Skipping...
# Processing Record 20 of Set 11 : gavrilovka vtoraya
# City not found. Skipping...
# Processing Record 21 of Set 11 : zalantun
# Processing Record 22 of Set 11 : antalaha
# Processing Record 23 of Set 11 : malabo
# Processing Record 24 of Set 11 : amalapuram
# Processing Record 25 of Set 11 : araria
# Processing Record 26 of Set 11 : san vicente
# City not found. Skipping...
# Processing Record 27 of Set 11 : yizheng
# Processing Record 28 of Set 11 : olafsvik
# Processing Record 29 of Set 11 : kalianget
# Processing Record 30 of Set 11 : keta
# Processing Record 31 of Set 11 : kidal
# Processing Record 32 of Set 11 : sarakhs
# Processing Record 33 of Set 11 : chikitigarh
# Processing Record 34 of Set 11 : bonthe
# Processing Record 35 of Set 11 : limon
# Processing Record 36 of Set 11 : harper
# Processing Record 37 of Set 11 : chitral
# Processing Record 38 of Set 11 : itainopolis
# City not found. Skipping...
# Processing Record 39 of Set 11 : brasilia
# Processing Record 40 of Set 11 : palmer
# Processing Record 41 of Set 11 : nanzhang
# Processing Record 42 of Set 11 : auki
# City not found. Skipping...
# Processing Record 43 of Set 11 : aberfeldy
# Processing Record 44 of Set 11 : napkor
# Processing Record 45 of Set 11 : broken hill
# Processing Record 46 of Set 11 : henties bay
# Processing Record 47 of Set 11 : yokadouma
# Processing Record 48 of Set 11 : adre
# City not found. Skipping...
# Processing Record 49 of Set 11 : bombay
# Processing Record 50 of Set 11 : bandrele
# Processing Record 0 of Set 12 : araguaina
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
# Create a panda data frame using data retrieved
weather_dict = pd.DataFrame({ 
                "City" : city_name_list,
                "Cloudiness" : cloudiness_list,
                "Country" : country_list,
                "Date" : date_list,
                "Humidity" : humidity_list,
                "Lat" : lat_list,
                "Lng" : lng_list,
                "Max Temp" : max_temp_list,
                "Wind Speed" : wind_speed_list
})

# %%
# Count data
weather_dict.count()
# Out:
# City          561
# Cloudiness    561
# Country       561
# Date          561
# Humidity      561
# Lat           561
# Lng           561
# Max Temp      561
# Wind Speed    561
# dtype: int64

# %%
# Display the Data Frame
weather_dict
# Out:
#               City  Cloudiness Country        Date  Humidity    Lat     Lng  \
# 0         Lüderitz           0      NA  1601721127        56 -26.65   15.16
# 1              Sur           0      OM  1601721127        38  22.57   59.53
# 2          Ahipara           4      NZ  1601721107        82 -35.17  173.17
# 3    Pimenta Bueno          65      BR  1601721128        84 -11.67  -61.19
# 4       Nikolskoye          52      RU  1601721047        62  59.70   30.79
# ..             ...         ...     ...         ...       ...    ...     ...
# 556      Yokadouma          96      CM  1601721283        68   3.52   15.05
# 557           Adré           0      TD  1601721283        37  13.47   22.20
# 558         Mumbai          75      IN  1601721056        79  19.01   72.85
# 559       Bandrele          24      YT  1601721284        66 -12.91   45.19
# 560      Araguaína          96      BR  1601721284        42  -7.19  -48.21
#
#      Max Temp  Wind Speed
# 0       64.53       14.32
# 1       90.90        7.87
# 2       51.91        2.77
# 3       74.25        1.34
# 4       63.00       13.42
# ..        ...         ...
# 556     83.82        1.74
# 557     90.27        6.38
# 558     87.80       11.41
# 559     86.00        6.93
# 560     86.58        6.40
#
# [561 rows x 9 columns]

# %%
# Save city data into a csv file
weather_dict.to_csv("../output_data/cities.csv", index = False)

# %% [markdown]
# ## Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# ## Latitude vs. Temperature Plot

# %%
# Create Latitude vs. Temperature Plot scatter plot
plt.scatter(weather_dict["Lat"], weather_dict["Max Temp"], facecolor = "steelblue", edgecolor = "black")

# Set title
plt.title("City Latitude vs. Max Temperature")

# Set x axis label
plt.xlabel("Laitude")

# Set y axis label
plt.ylabel("Max Temperature (F)")

# Set grid line
plt.grid(linestyle='-', linewidth=1, alpha = 0.5)

# Save the plotted figure as .pngs
plt.savefig("../Images/City Latitude vs Max Temperature.png")

# %% [markdown]
# ## Latitude vs. Humidity Plot

# %%
# Create Latitude vs. Humidity Plot scatter plot
plt.scatter(weather_dict["Lat"], weather_dict["Humidity"], facecolor = "steelblue", edgecolor = "black")

# Set title
plt.title("City Latitude vs. Humidity")

# Set x axis label
plt.xlabel("Laitude")

# Set y axis label
plt.ylabel("Humidity (%)")

# Set grid line
plt.grid(linestyle='-', linewidth=1, alpha = 0.5)

# Save the plotted figure as .pngs
plt.savefig("../Images/City Latitude vs Humidity.png")

# %% [markdown]
# ## Latitude vs. Cloudiness Plot

# %%
# Create Latitude vs. Cloudiness Plot scatter plot
plt.scatter(weather_dict["Lat"], weather_dict["Cloudiness"], facecolor = "steelblue", edgecolor = "black")

# Set title
plt.title("City Latitude vs. Cloudiness")

# Set x axis label
plt.xlabel("Laitude")

# Set y axis label
plt.ylabel("Cloudiness (%)")

# Set y axis limit
plt.ylim(-5,105)

# Set grid line
plt.grid(linestyle='-', linewidth=1, alpha = 0.5)

# Save the plotted figure as .pngs
plt.savefig("../Images/City Latitude vs Cloudiness.png")

# %% [markdown]
# ## Latitude vs. Wind Speed Plot

# %%
# Create Latitude vs. Wind Speed scatter plot
plt.scatter(weather_dict["Lat"], weather_dict["Wind Speed"], facecolor = "steelblue", edgecolor = "black")
plt.title("City Latitude vs. Wind Speed (mph)")

# Set x axis label
plt.xlabel("Laitude")

# Set y axis label
plt.ylabel("Wind Speed (%)")

# Set y axis limit
plt.ylim(-2,50)

# Set grid line
plt.grid(linestyle='-', linewidth=1, alpha = 0.5)

# Save the plotted figure as .pngs
plt.savefig("../Images/City Latitude vs Wind Speed (mph).png")

# %% [markdown]
# ## Linear Regression

# %%
# Create Northern and Southern Hemisphere DataFrames
northern_hemisphere = weather_dict.loc[weather_dict["Lat"] >= 0]
southern_hemisphere = weather_dict.loc[weather_dict["Lat"] < 0]

# %%
# Define function for creating linear agression and scatter plot
def linear_agression(x,y):
    print(f"The r-squared is : {round(st.pearsonr(x, y)[0],2)}")
    (slope, intercept, rvalue, pvalue, stderr) = linregress(x, y)
    regress_values = x * slope + intercept
    line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
    plt.scatter(x, y)
    plt.plot(x,regress_values,"r-")
    return line_eq

# Define a fuction for annotating
def annotate(line_eq, a, b):
    plt.annotate(line_eq,(a,b),fontsize=15,color="red")

# %% [markdown]
# ####  Northern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
# Call an function #1
equation = linear_agression(northern_hemisphere["Lat"], northern_hemisphere["Max Temp"])

# Call an function #2
annotate(equation, 0, 0)

# Set a title
plt.title("Northern Hemisphere - Max Temp vs. Latitude Linear Regression")

# Set xlabel
plt.xlabel("Latitude")

# Set ylabel
plt.ylabel("Max Temp (F)")

# Save the figure
plt.savefig("../Images/Northern Hemisphere - Max Temp vs. Latitude Linear Regression.png")
# Out:
# The r-squared is : -0.82

# %% [markdown]
# ####  Southern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
# Call an function #1
equation = linear_agression(southern_hemisphere["Lat"],southern_hemisphere["Max Temp"])

# Call an function #2
annotate(equation, -30, 50)

# Set a title
plt.title("Southern Hemisphere - Max Temp vs. Latitude Linear Regression")

# Set xlabel
plt.xlabel("Latitude")

# Set ylabel
plt.ylabel("Max Temp (F)")

# Save the figure
plt.savefig("../Images/Southern Hemisphere - Max Temp vs. Latitude Linear Regression.png")
# Out:
# The r-squared is : 0.73

# %% [markdown]
# ####  Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
# Call an function #1
equation = linear_agression(northern_hemisphere["Lat"], northern_hemisphere["Humidity"])

# Call an function #2
annotate(equation, 40, 15)

# Set a title
plt.title("Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression")

# Set xlabel
plt.xlabel("Latitude")

# Set ylabel
plt.ylabel("Humidity (%)")

# Save the figure
plt.savefig("../Images/Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression.png")
# Out:
# The r-squared is : 0.27

# %% [markdown]
# ####  Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
# Call an function #1
equation = linear_agression(southern_hemisphere["Lat"], southern_hemisphere["Humidity"])

# Call an function #2
annotate(equation, -40, 50)

# Set title
plt.title("Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression")

# Set xlabel
plt.xlabel("Latitude")

# Set ylabel
plt.ylabel("Humidity (%)")

# Save the figure
plt.savefig("../Images/Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression.png")
# Out:
# The r-squared is : -0.03

# %% [markdown]
# ####  Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
# Call an function #1
equation = linear_agression(northern_hemisphere["Lat"], northern_hemisphere["Cloudiness"])

# Call an function #2
annotate(equation, 30, 40)

# Set a title
plt.title("Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression")

# Set xlabel
plt.xlabel("Latitude")

# Set ylabel
plt.ylabel("Cloudiness (%)")

# Save the figure
plt.savefig("../Images/Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression.png")
# Out:
# The r-squared is : 0.24

# %% [markdown]
# ####  Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
# Call an function #1
equation = linear_agression(southern_hemisphere["Lat"], southern_hemisphere["Cloudiness"])

# Call an function #2
annotate(equation, -30, 40)

# Set a title
plt.title("Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression")

# Set xlabel
plt.xlabel("Latitude")

# Set ylabel
plt.ylabel("Cloudiness (%)")

# Save the figure
plt.savefig("../Images/Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression.png")
# Out:
# The r-squared is : -0.1

# %% [markdown]
# ####  Northern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
# Call an function #1
equation = linear_agression(northern_hemisphere["Lat"], northern_hemisphere["Wind Speed"])

# Call an function #2
annotate(equation, 40, 20)

# Set  title
plt.title("Northern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression")

# Set xlabel
plt.xlabel("Latitude")

# Set ylabel
plt.ylabel("Wind Speed (mph)")

# Save the figure
plt.savefig("../Images/Northern Hemisphere - Wind Speed vs. Latitude Linear Regression.png")
# Out:
# The r-squared is : 0.17

# %% [markdown]
# ####  Southern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
# Call an function #1
equation = linear_agression(southern_hemisphere["Lat"], southern_hemisphere["Wind Speed"])

# Call an function #2
annotate(equation, -30, 15)

# Set  title
plt.title("Southern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression")

# Set xlabel
plt.xlabel("Latitude")

# Set ylabel
plt.ylabel("Wind Speed (mph)")

# Save the figure
plt.savefig("../Images/Southern Hemisphere - Wind Speed vs. Latitude Linear Regression.png")
# Out:
# The r-squared is : -0.21
